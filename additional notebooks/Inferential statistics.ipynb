# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Simulate experiment of flipping a coin 4 times, find probability of getting 4 heads.

# %%
np.random.random()
# Out:
# 0.9347209125980855

# %%
np.random.random(5)
# Out:
# array([0.05951867, 0.47940262, 0.34042965, 0.80228657, 0.57267394])

# %%
np.random.seed(42)
random_numbers = np.random.random(4)
random_numbers
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848])

# %%
heads = random_numbers < 0.5
heads
# Out:
# array([ True, False, False, False])

# %%
np.sum(heads)
# Out:
# 1

# %% [markdown]
# Lets simulate the experiment for 10000 times

# %%
n_4_heads = 0
for _ in range(10000):
    heads = np.random.random(4) < 0.5
    n_heads = heads.sum()
    if n_heads == 4:
        n_4_heads += 1
        
n_4_heads / 10000
# Out:
# 0.0619

# %% [markdown]
# ### Find distribution of random numbers generated

# %%
numbers = []

# try different values for n
for _ in range(100):
    numbers.append(np.random.random())

sns.set()
_ = plt.hist(numbers)
plt.show()

# %%
samples_std1 = np.random.normal(20, 1, size=100000)
samples_std3 = np.random.normal(20, 3, size=10000)
samples_std10 = np.random.normal(20, 10, size=10000)

# %%
_ = plt.hist(samples_std1, bins=100, histtype='step', density=True, stacked=True)

plt.show()
